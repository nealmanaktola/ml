# %%
from utils import load_grades_data, load_heart_data, generate_silhoutte_score_plot
from sklearn.cluster import KMeans
from sklearn import metrics

# %%
X, y = load_heart_data()

# %%
X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4p/41bttzcx5y163sbdhm1bfdl40000gn/T/ipykernel_17741/2424826063.py in <module>
# ----> 1 X.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
print(X)
# Out:
# [[ 0.9521966   0.68100522  0.76395577 ...  3.66450153 -0.92676626
#   -0.93914194]
#  [-1.91531289  0.68100522 -0.09273778 ...  3.66450153 -0.92676626
#   -0.93914194]
#  [-1.47415758 -1.46841752 -0.09273778 ... -0.27288841 -0.92676626
#    1.06480177]
#  ...
#  [ 1.50364073  0.68100522  0.70684287 ... -0.27288841  1.07902072
#   -0.93914194]
#  [ 0.29046364  0.68100522 -0.09273778 ... -0.27288841  1.07902072
#   -0.93914194]
#  [ 0.29046364 -1.46841752 -0.09273778 ... -0.27288841  1.07902072
#   -0.93914194]]

# %%
generate_silhoutte_score_plot(X, 21, KMeans)

# %%
X
# Out:
# array([[ 0.9521966 ,  0.68100522,  0.76395577, ...,  3.66450153,
#         -0.92676626, -0.93914194],
#        [-1.91531289,  0.68100522, -0.09273778, ...,  3.66450153,
#         -0.92676626, -0.93914194],
#        [-1.47415758, -1.46841752, -0.09273778, ..., -0.27288841,
#         -0.92676626,  1.06480177],
#        ...,
#        [ 1.50364073,  0.68100522,  0.70684287, ..., -0.27288841,
#          1.07902072, -0.93914194],
#        [ 0.29046364,  0.68100522, -0.09273778, ..., -0.27288841,
#          1.07902072, -0.93914194],
#        [ 0.29046364, -1.46841752, -0.09273778, ..., -0.27288841,
#          1.07902072, -0.93914194]])

# %%
X[0]
# Out:
# array([ 0.9521966 ,  0.68100522,  0.76395577, -0.25633371,  2.394438  ,
#        -1.00583187,  0.01544279, -0.69663055,  1.08733806, -0.71442887,
#        -0.94538352, -0.44455422, -0.63464776,  3.4891135 , -0.08151391,
#         3.97911213, -1.10076284, -0.79311554,  3.66450153, -0.92676626,
#        -0.93914194])

# %%
generate_silhoutte_score_plot(X, 10, KMeans)

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
X
# Out:
# array([[ 0.9521966 ,  0.68100522,  0.76395577, ...,  3.66450153,
#         -0.92676626, -0.93914194],
#        [-1.91531289,  0.68100522, -0.09273778, ...,  3.66450153,
#         -0.92676626, -0.93914194],
#        [-1.47415758, -1.46841752, -0.09273778, ..., -0.27288841,
#         -0.92676626,  1.06480177],
#        ...,
#        [ 1.50364073,  0.68100522,  0.70684287, ..., -0.27288841,
#          1.07902072, -0.93914194],
#        [ 0.29046364,  0.68100522, -0.09273778, ..., -0.27288841,
#          1.07902072, -0.93914194],
#        [ 0.29046364, -1.46841752, -0.09273778, ..., -0.27288841,
#          1.07902072, -0.93914194]])

# %%
len(X)
# Out:
# 303

# %%
len(X[0])
# Out:
# 21

# %%
clusterer = KMeans(n_clusters=5, random_state=10)

# %%
cluster_labels = clusterer.fit_predict(X)

# %%
silhouette_avg = metrics.silhouette_score(X, cluster_labels)
