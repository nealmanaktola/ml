# %%
from utils import load_grades_data, load_heart_data,load_wine_data, generate_silhoutte_score_plot, generate_kmeans_SV_ICD_plots, generate_distance_bw_gmms_plots, generate_bic_plot
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.mixture import GaussianMixture

# %%
X = load_wine_data()

# %%
X
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
print(X)
# Out:
# [[ 1.51861254 -0.5622498   0.23205254 ...  0.36217728  1.84791957
#    1.01300893]
#  [ 0.24628963 -0.49941338 -0.82799632 ...  0.40605066  1.1134493
#    0.96524152]
#  [ 0.19687903  0.02123125  1.10933436 ...  0.31830389  0.78858745
#    1.39514818]
#  ...
#  [ 0.33275817  1.74474449 -0.38935541 ... -1.61212515 -1.48544548
#    0.28057537]
#  [ 0.20923168  0.22769377  0.01273209 ... -1.56825176 -1.40069891
#    0.29649784]
#  [ 1.39508604  1.58316512  1.36520822 ... -1.52437837 -1.42894777
#   -0.59516041]]

# %%
generate_silhoutte_score_plot(X, 10, KMeans)

# %%
X
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
X[0]
# Out:
# array([ 1.51861254, -0.5622498 ,  0.23205254, -1.16959318,  1.91390522,
#         0.80899739,  1.03481896, -0.65956311,  1.22488398,  0.25171685,
#         0.36217728,  1.84791957,  1.01300893])

# %%
generate_silhoutte_score_plot(X, 10, KMeans)

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4p/41bttzcx5y163sbdhm1bfdl40000gn/T/ipykernel_33864/859018229.py in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
X
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
len(X)
# Out:
# 178

# %%
len(X[0])
# Out:
# 13

# %%
clusterer = KMeans(n_clusters=5, random_state=10)

# %%
cluster_labels = clusterer.fit_predict(X)

# %%
silhouette_avg = metrics.silhouette_score(X, cluster_labels)

# %%
print("silhouette_score", silhouette_avg)
# Out:
# silhouette_score 0.19734439798042422

# %%
k = list(range(2,15))
generate_kmeans_SV_ICD_plots(X, k)
# Out:
# /opt/miniconda3/lib/python3.8/site-packages/sklearn/manifold/_mds.py:419: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %%
k = list(range(2,8))
generate_kmeans_SV_ICD_plots(X, k)

# %%
k = list(range(2,5))
generate_kmeans_SV_ICD_plots(X, k)

# %%
k = list(range(8,12))
generate_kmeans_SV_ICD_plots(X, k)

# %%
generate_silhoutte_score_plot(X, 10, GaussianMixture)

# %%
generate_distance_bw_gmms_plots(X, 20)

# %%
generate_bic_plot(X, 20)
